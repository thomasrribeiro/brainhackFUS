# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pydicom
import numpy as np

skull_dicom = pydicom.dcmread("../data/skull_slice.dcm")
skull_array = skull_dicom.pixel_array.astype(np.int16)
skull_array = skull_array[:500, 200:-200]

# threshold = 20000
# skull_mask = skull_array > threshold
# skull_array[~skull_mask] = 0

# %%
import matplotlib.pyplot as plt
plt.imshow(skull_array, cmap='gray')
plt.colorbar()
plt.show()

# %%
np.max(skull_array)
# Out:
# np.int16(25344)

# %%
np.min(skull_array)
# Out:
# np.int16(16501)
